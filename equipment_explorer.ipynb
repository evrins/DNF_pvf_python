# %%
import polars as pl

# %%
df = pl.read_parquet(
    '/Users/evrins/workspace/python/DNF_pvf_python/dnfpkgtool/repo/data/equipments.parquet'
)
df
# Out:
# shape: (63_788, 30)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ id        ┆ name      ┆ name2     ┆ json      ┆ … ┆ armor_typ ┆ display_e ┆ display_r ┆ display_ │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ e         ┆ quipment_ ┆ arity     ┆ usable_j │
# │ i64       ┆ str       ┆ str       ┆ str       ┆   ┆ ---       ┆ type      ┆ ---       ┆ ob       │
# │           ┆           ┆           ┆           ┆   ┆ str       ┆ ---       ┆ str       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆ str       ┆           ┆ str      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 10018     ┆ (旧) 古老 ┆ Old Wool  ┆ {"[name]" ┆ … ┆ cl        ┆ 上衣      ┆ 普通      ┆ 全部职业 │
# │           ┆ 的羊毛背  ┆ Vest      ┆ : ["(旧)  ┆   ┆           ┆           ┆           ┆          │
# ...

# %%
df.schema
# Out:
# Schema([('id', Int64),
#         ('name', String),
#         ('name2', String),
#         ('json', String),
#         ('level', Int64),
#         ('rarity', Int64),
#         ('equipment_type', String),
#         ('sub_equipment_type', Int64),
#         ('item_group_name', String),
#         ('usable_job', List(String)),
#         ('physical_attack', Int64),
#         ('magical_attack', Int64),
#         ('physical_defense', Int64),
#         ('magical_defense', Int64),
#         ('physical_critical_hit', Float64),
#         ('magical_critical_hit', Float64),
#         ('all_elemental_attack', Int64),
#         ('attack_speed', Int64),
#         ('cast_speed', Int64),
#         ('move_speed', Int64),
#         ('room_list_move_speed_rate', Float64),
#         ('mp_max_rate', Int64),
#         ('set_name', String),
#         ('set_item', List(Int64)),
#         ('durability', Int64),
#         ('sub_type', Int64),
#         ('armor_type', String),
# ...

# %%
df.select(pl.col('equipment_type')).sort(pl.col('equipment_type')).unique()
# Out:
# shape: (27, 1)
# ┌──────────────────┐
# │ equipment_type   │
# │ ---              │
# │ str              │
# ╞══════════════════╡
# │                  │
# │ [amulet]         │
# │ [artifact blue]  │
# │ [artifact green] │
# │ [artifact red]   │
# │ …                │
# │ [title name]     │
# │ [waist avatar]   │
# │ [waist]          │
# │ [weapon]         │
# │ [wrist]          │
# └──────────────────┘

# %%
df.filter((pl.col('equipment_type') == '[coat avatar]') & (pl.col('name') != ''))
# Out:
# shape: (3_483, 30)
# ┌───────────┬────────────┬───────┬────────────┬───┬────────────┬───────────┬───────────┬───────────┐
# │ id        ┆ name       ┆ name2 ┆ json       ┆ … ┆ armor_type ┆ display_e ┆ display_r ┆ display_u │
# │ ---       ┆ ---        ┆ ---   ┆ ---        ┆   ┆ ---        ┆ quipment_ ┆ arity     ┆ sable_job │
# │ i64       ┆ str        ┆ str   ┆ str        ┆   ┆ str        ┆ type      ┆ ---       ┆ ---       │
# │           ┆            ┆       ┆            ┆   ┆            ┆ ---       ┆ str       ┆ str       │
# │           ┆            ┆       ┆            ┆   ┆            ┆ str       ┆           ┆           │
# ╞═══════════╪════════════╪═══════╪════════════╪═══╪════════════╪═══════════╪═══════════╪═══════════╡
# │ 103500119 ┆ 层叠式运动 ┆       ┆ {"[name]": ┆ … ┆            ┆ 上衣装扮  ┆ 普通      ┆ 格斗家-男 │
# │           ┆ 衫[A型]    ┆       ┆ ["层叠式运 ┆   ┆            ┆           ┆           ┆           │
# ...

# %%
df.filter((pl.col('equipment_type') == '') & (pl.col('name') != ''))
# Out:
# shape: (8, 30)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ id        ┆ name      ┆ name2     ┆ json      ┆ … ┆ armor_typ ┆ display_e ┆ display_r ┆ display_ │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ e         ┆ quipment_ ┆ arity     ┆ usable_j │
# │ i64       ┆ str       ┆ str       ┆ str       ┆   ┆ ---       ┆ type      ┆ ---       ┆ ob       │
# │           ┆           ┆           ┆           ┆   ┆ str       ┆ ---       ┆ str       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆ str       ┆           ┆ str      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 2312900   ┆ 成长之契  ┆           ┆ {"[name]" ┆ … ┆           ┆ 契约效果  ┆ 高级      ┆ 全部职业 │
# │           ┆ 约        ┆           ┆ : ["成长  ┆   ┆           ┆           ┆           ┆          │
# ...

# %%
df.filter((pl.col('equipment_type') == '[amulet]') & (pl.col('name') != ''))
# Out:
# shape: (1_850, 30)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ id        ┆ name      ┆ name2     ┆ json      ┆ … ┆ armor_typ ┆ display_e ┆ display_r ┆ display_ │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ e         ┆ quipment_ ┆ arity     ┆ usable_j │
# │ i64       ┆ str       ┆ str       ┆ str       ┆   ┆ ---       ┆ type      ┆ ---       ┆ ob       │
# │           ┆           ┆           ┆           ┆   ┆ str       ┆ ---       ┆ str       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆ str       ┆           ┆ str      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 20013     ┆ (旧) 褪色 ┆ Fade      ┆ {"[name]" ┆ … ┆           ┆ 项链      ┆ 普通      ┆ 全部职业 │
# │           ┆ 的青铜项  ┆ Bronze    ┆ : ["(旧)  ┆   ┆           ┆           ┆           ┆          │
# ...

# %%
df.filter((pl.col('equipment_type') == '[artifact green]') & (pl.col('name') != ''))
# Out:
# shape: (23, 30)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ id        ┆ name      ┆ name2     ┆ json      ┆ … ┆ armor_typ ┆ display_e ┆ display_r ┆ display_ │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ e         ┆ quipment_ ┆ arity     ┆ usable_j │
# │ i64       ┆ str       ┆ str       ┆ str       ┆   ┆ ---       ┆ type      ┆ ---       ┆ ob       │
# │           ┆           ┆           ┆           ┆   ┆ str       ┆ ---       ┆ str       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆ str       ┆           ┆ str      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 64500     ┆ Artifect  ┆ Artifect  ┆ {"[name]" ┆ … ┆           ┆ 绿色      ┆ 稀有      ┆ 全部职业 │
# │           ┆ Green     ┆ Green     ┆ : [""],   ┆   ┆           ┆ 宠物装备  ┆           ┆          │
# ...

# %%
df.filter((pl.col('equipment_type') == '[aurora avatar]') & (pl.col('name') != ''))
# Out:
# shape: (268, 30)
# ┌───────────┬────────────┬───────┬────────────┬───┬────────────┬───────────┬───────────┬───────────┐
# │ id        ┆ name       ┆ name2 ┆ json       ┆ … ┆ armor_type ┆ display_e ┆ display_r ┆ display_u │
# │ ---       ┆ ---        ┆ ---   ┆ ---        ┆   ┆ ---        ┆ quipment_ ┆ arity     ┆ sable_job │
# │ i64       ┆ str        ┆ str   ┆ str        ┆   ┆ str        ┆ type      ┆ ---       ┆ ---       │
# │           ┆            ┆       ┆            ┆   ┆            ┆ ---       ┆ str       ┆ str       │
# │           ┆            ┆       ┆            ┆   ┆            ┆ str       ┆           ┆           │
# ╞═══════════╪════════════╪═══════╪════════════╪═══╪════════════╪═══════════╪═══════════╪═══════════╡
# │ 107590007 ┆ 迅捷的奥拉 ┆       ┆ {"[name]": ┆ … ┆            ┆ 光环      ┆ 普通      ┆ 格斗家    │
# │           ┆ 光环[格斗  ┆       ┆ ["迅捷的奥 ┆   ┆            ┆           ┆           ┆           │
# ...

# %%
df.filter((pl.col('equipment_type') == '[breast avatar]') & (pl.col('name') != ''))
# Out:
# shape: (2_784, 30)
# ┌───────────┬────────────┬───────┬────────────┬───┬────────────┬───────────┬───────────┬───────────┐
# │ id        ┆ name       ┆ name2 ┆ json       ┆ … ┆ armor_type ┆ display_e ┆ display_r ┆ display_u │
# │ ---       ┆ ---        ┆ ---   ┆ ---        ┆   ┆ ---        ┆ quipment_ ┆ arity     ┆ sable_job │
# │ i64       ┆ str        ┆ str   ┆ str        ┆   ┆ str        ┆ type      ┆ ---       ┆ ---       │
# │           ┆            ┆       ┆            ┆   ┆            ┆ ---       ┆ str       ┆ str       │
# │           ┆            ┆       ┆            ┆   ┆            ┆ str       ┆           ┆           │
# ╞═══════════╪════════════╪═══════╪════════════╪═══╪════════════╪═══════════╪═══════════╪═══════════╡
# │ 103520132 ┆ 简约围巾[A ┆       ┆ {"[name]": ┆ … ┆            ┆ 胸部装扮  ┆ 普通      ┆ 格斗家-男 │
# │           ┆ 型]        ┆       ┆ ["简约围巾 ┆   ┆            ┆           ┆           ┆           │
# ...

# %%
df.filter((pl.col('equipment_type') == '[creature]') & (pl.col('name') != ''))
# Out:
# shape: (233, 30)
# ┌───────────┬───────────┬──────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ id        ┆ name      ┆ name2    ┆ json      ┆ … ┆ armor_typ ┆ display_e ┆ display_r ┆ display_u │
# │ ---       ┆ ---       ┆ ---      ┆ ---       ┆   ┆ e         ┆ quipment_ ┆ arity     ┆ sable_job │
# │ i64       ┆ str       ┆ str      ┆ str       ┆   ┆ ---       ┆ type      ┆ ---       ┆ ---       │
# │           ┆           ┆          ┆           ┆   ┆ str       ┆ ---       ┆ str       ┆ str       │
# │           ┆           ┆          ┆           ┆   ┆           ┆ str       ┆           ┆           │
# ╞═══════════╪═══════════╪══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 63000     ┆ 佛拉斯    ┆ Faras    ┆ {"[name]" ┆ … ┆           ┆ 宠物      ┆ 高级      ┆ 全部职业  │
# │           ┆           ┆          ┆ : ["佛拉  ┆   ┆           ┆           ┆           ┆           │
# ...

# %%
df.filter((pl.col('equipment_type') == '[support]') & (pl.col('name') != ''))
# Out:
# shape: (967, 30)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ id        ┆ name      ┆ name2     ┆ json      ┆ … ┆ armor_typ ┆ display_e ┆ display_r ┆ display_ │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ e         ┆ quipment_ ┆ arity     ┆ usable_j │
# │ i64       ┆ str       ┆ str       ┆ str       ┆   ┆ ---       ┆ type      ┆ ---       ┆ ob       │
# │           ┆           ┆           ┆           ┆   ┆ str       ┆ ---       ┆ str       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆ str       ┆           ┆ str      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 440000    ┆ 古老的丝  ┆ Old Silky ┆ {"[name]" ┆ … ┆           ┆ 辅助装备  ┆ 普通      ┆ 全部职业 │
# │           ┆ 绒臂章    ┆ Yarn      ┆ : ["古老  ┆   ┆           ┆           ┆           ┆          │
# ...

# %%
df.filter((pl.col('equipment_type') == '[weapon]') & (pl.col('name') != ''))
# Out:
# shape: (7_915, 30)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ id        ┆ name      ┆ name2     ┆ json      ┆ … ┆ armor_typ ┆ display_e ┆ display_r ┆ display_ │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ e         ┆ quipment_ ┆ arity     ┆ usable_j │
# │ i64       ┆ str       ┆ str       ┆ str       ┆   ┆ ---       ┆ type      ┆ ---       ┆ ob       │
# │           ┆           ┆           ┆           ┆   ┆ str       ┆ ---       ┆ str       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆ str       ┆           ┆ str      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 29000     ┆ 普通手套  ┆ Default   ┆ {"[name]" ┆ … ┆           ┆ 手套      ┆ 普通      ┆ 格斗家,  │
# │           ┆           ┆ Gloves    ┆ : ["普通  ┆   ┆           ┆           ┆           ┆ 格斗家-  │
# ...

# %%
df.filter(pl.col('id') == 11338)
# Out:
# shape: (1, 30)
# ┌───────┬────────────┬────────────┬────────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ id    ┆ name       ┆ name2      ┆ json       ┆ … ┆ armor_typ ┆ display_e ┆ display_r ┆ display_u │
# │ ---   ┆ ---        ┆ ---        ┆ ---        ┆   ┆ e         ┆ quipment_ ┆ arity     ┆ sable_job │
# │ i64   ┆ str        ┆ str        ┆ str        ┆   ┆ ---       ┆ type      ┆ ---       ┆ ---       │
# │       ┆            ┆            ┆            ┆   ┆ str       ┆ ---       ┆ str       ┆ str       │
# │       ┆            ┆            ┆            ┆   ┆           ┆ str       ┆           ┆           │
# ╞═══════╪════════════╪════════════╪════════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 11338 ┆ 古老的鳞岩 ┆ Low-Cost   ┆ {"[name]": ┆ … ┆ ha        ┆ 上衣      ┆ 稀有      ┆ 全部职业  │
# │       ┆ 胸甲       ┆ Carbollite ┆ ["古老的鳞 ┆   ┆           ┆           ┆           ┆           │
# ...

# %%
df.select(pl.col('item_group_name')).unique()
# Out:
# shape: (59, 1)
# ┌─────────────────┐
# │ item_group_name │
# │ ---             │
# │ str             │
# ╞═════════════════╡
# │ staff           │
# │ totem           │
# │ katana          │
# │ support         │
# │ claw            │
# │ …               │
# │ lt coat         │
# │ ring            │
# │ lt shoes        │
# │ bglove          │
# │ ssword          │
# └─────────────────┘

# %%
df.select(pl.col('equipment_type')).unique()
# Out:
# shape: (27, 1)
# ┌─────────────────┐
# │ equipment_type  │
# │ ---             │
# │ str             │
# ╞═════════════════╡
# │ [skin avatar]   │
# │ [face avatar]   │
# │ [weapon]        │
# │ [pants]         │
# │ [amulet]        │
# │ …               │
# │ [artifact blue] │
# │ [creature]      │
# │ [coat]          │
# │ [shoes]         │
# │ [waist]         │
# └─────────────────┘

# %%
df.filter((pl.col('equipment_type') == '[title name]') & (pl.col('name') != ''))
# Out:
# shape: (762, 30)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ id        ┆ name      ┆ name2     ┆ json      ┆ … ┆ armor_typ ┆ display_e ┆ display_r ┆ display_ │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ e         ┆ quipment_ ┆ arity     ┆ usable_j │
# │ i64       ┆ str       ┆ str       ┆ str       ┆   ┆ ---       ┆ type      ┆ ---       ┆ ob       │
# │           ┆           ┆           ┆           ┆   ┆ str       ┆ ---       ┆ str       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆ str       ┆           ┆ str      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 26001     ┆ (旧) 卡妮 ┆ Kanna's   ┆ {"[name]" ┆ … ┆           ┆ 称号      ┆ 稀有      ┆ 全部职业 │
# │           ┆ 娜的希望☆ ┆ slave     ┆ : ["(旧)  ┆   ┆           ┆           ┆           ┆          │
# ...

# %%
df.filter(pl.col('name') == '守护腰带')
# Out:
# shape: (1, 30)
# ┌───────┬──────────┬────────────┬────────────┬───┬────────────┬────────────┬───────────┬───────────┐
# │ id    ┆ name     ┆ name2      ┆ json       ┆ … ┆ armor_type ┆ display_eq ┆ display_r ┆ display_u │
# │ ---   ┆ ---      ┆ ---        ┆ ---        ┆   ┆ ---        ┆ uipment_ty ┆ arity     ┆ sable_job │
# │ i64   ┆ str      ┆ str        ┆ str        ┆   ┆ str        ┆ pe         ┆ ---       ┆ ---       │
# │       ┆          ┆            ┆            ┆   ┆            ┆ ---        ┆ str       ┆ str       │
# │       ┆          ┆            ┆            ┆   ┆            ┆ str        ┆           ┆           │
# ╞═══════╪══════════╪════════════╪════════════╪═══╪════════════╪════════════╪═══════════╪═══════════╡
# │ 17242 ┆ 守护腰带 ┆ Protection ┆ {"[name]": ┆ … ┆ ha         ┆ 腰带       ┆ 稀有      ┆ 全部职业  │
# │       ┆          ┆ Belt       ┆ ["守护腰带 ┆   ┆            ┆            ┆           ┆           │
# ...

# %%
df.filter(pl.col('display_rarity') == '史诗')
# Out:
# shape: (1_338, 30)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ id        ┆ name      ┆ name2     ┆ json      ┆ … ┆ armor_typ ┆ display_e ┆ display_r ┆ display_ │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ e         ┆ quipment_ ┆ arity     ┆ usable_j │
# │ i64       ┆ str       ┆ str       ┆ str       ┆   ┆ ---       ┆ type      ┆ ---       ┆ ob       │
# │           ┆           ┆           ┆           ┆   ┆ str       ┆ ---       ┆ str       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆ str       ┆           ┆ str      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 10114     ┆ (旧) 银月 ┆ Spangle   ┆ {"[name]" ┆ … ┆ cl        ┆ 上衣      ┆ 史诗      ┆ 全部职业 │
# │           ┆ 少女T恤衫 ┆ Girl      ┆ : ["(旧)  ┆   ┆           ┆           ┆           ┆          │
# ...

# %%
df.filter(pl.col('all_elemental_attack') != 0).sort(
    pl.col('all_elemental_attack'), descending=True
)
# Out:
# shape: (319, 30)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ id        ┆ name      ┆ name2     ┆ json      ┆ … ┆ armor_typ ┆ display_e ┆ display_r ┆ display_ │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ e         ┆ quipment_ ┆ arity     ┆ usable_j │
# │ i64       ┆ str       ┆ str       ┆ str       ┆   ┆ ---       ┆ type      ┆ ---       ┆ ob       │
# │           ┆           ┆           ┆           ┆   ┆ str       ┆ ---       ┆ str       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆ str       ┆           ┆ str      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 100350017 ┆ 高级精灵  ┆           ┆ {"[name]" ┆ … ┆           ┆ 魔法石    ┆ 史诗      ┆ 全部职业 │
# │           ┆ 的精炼宝  ┆           ┆ : ["高级  ┆   ┆           ┆           ┆           ┆          │
# ...

# %%
df.filter(pl.col('equipment_type') == '[weapon]').select(
    pl.col('item_group_name')
).unique()
# Out:
# shape: (28, 1)
# ┌─────────────────┐
# │ item_group_name │
# │ ---             │
# │ str             │
# ╞═════════════════╡
# │ beamswd         │
# │ twinswd         │
# │ wand            │
# │ rod             │
# │ broom           │
# │ …               │
# │ bglove          │
# │ revolver        │
# │ knuckle         │
# │ hcannon         │
# │ claw            │
# └─────────────────┘

# %%
df.filter(pl.col('id').is_in(list(range(2747697, 2747702))))
# Out:
# shape: (5, 30)
# ┌─────────┬────────────┬───────┬────────────┬───┬────────────┬────────────┬────────────┬───────────┐
# │ id      ┆ name       ┆ name2 ┆ json       ┆ … ┆ armor_type ┆ display_eq ┆ display_ra ┆ display_u │
# │ ---     ┆ ---        ┆ ---   ┆ ---        ┆   ┆ ---        ┆ uipment_ty ┆ rity       ┆ sable_job │
# │ i64     ┆ str        ┆ str   ┆ str        ┆   ┆ str        ┆ pe         ┆ ---        ┆ ---       │
# │         ┆            ┆       ┆            ┆   ┆            ┆ ---        ┆ str        ┆ str       │
# │         ┆            ┆       ┆            ┆   ┆            ┆ str        ┆            ┆           │
# ╞═════════╪════════════╪═══════╪════════════╪═══╪════════════╪════════════╪════════════╪═══════════╡
# │ 2747697 ┆ 骑士王的守 ┆       ┆ {"[name]": ┆ … ┆            ┆ 称号       ┆ 神器       ┆ 全部职业  │
# │         ┆ 护         ┆       ┆ ["骑士王的 ┆   ┆            ┆            ┆            ┆           │
# ...

# %%
df.filter(pl.col('set_name') != '').select(pl.col('set_name'), pl.col('set_item')).sort(
    pl.col('set_name'), descending=True
)
# Out:
# shape: (1_107, 2)
# ┌─────────────────────────────┬─────────────────────────┐
# │ set_name                    ┆ set_item                │
# │ ---                         ┆ ---                     │
# │ str                         ┆ list[i64]               │
# ╞═════════════════════════════╪═════════════════════════╡
# │ 龙鸣重甲  套装              ┆ [11237, 13237, … 19234] │
# │ 龙鸣重甲  套装              ┆ [11259, 13259, … 17256] │
# │ 龙脊轻甲  套装              ┆ [10874, 12874, … 16873] │
# │ 黑龙汲星轻甲  套装          ┆ [10875, 12875, … 16874] │
# │ 黑豹突击者轻甲  套装        ┆ [10934, 12928, … 18926] │
# │ …                           ┆ …                       │
# │ 2010年夏日  套装 1 (神枪手) ┆ [47201, 47619, … 50220] │
# │ 2010年夏日  套装 1 (格斗家) ┆ [43196, 43624, … 46220] │
# │ 2010年夏日  套装 1 (圣职者) ┆ [55135, 55514, … 58220] │
# │ (旧) 窒息的悲鸣首饰         ┆ [20167, 22160, 24175]   │
# │ (旧) 泰拉石首饰             ┆ [20166, 22159, 24174]   │
# └─────────────────────────────┴─────────────────────────┘

# %%
df.select('*').sort(pl.col('cast_speed'), descending=True)
# Out:
# shape: (63_788, 30)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ id        ┆ name      ┆ name2     ┆ json      ┆ … ┆ armor_typ ┆ display_e ┆ display_r ┆ display_ │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ e         ┆ quipment_ ┆ arity     ┆ usable_j │
# │ i64       ┆ str       ┆ str       ┆ str       ┆   ┆ ---       ┆ type      ┆ ---       ┆ ob       │
# │           ┆           ┆           ┆           ┆   ┆ str       ┆ ---       ┆ str       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆ str       ┆           ┆ str      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 22183     ┆ 简易白瓷  ┆ Upgrade   ┆ {"[name]" ┆ … ┆           ┆ 手镯      ┆ 普通      ┆ 全部职业 │
# │           ┆ 手镯      ┆ Ceramics  ┆ : ["简易  ┆   ┆           ┆           ┆           ┆          │
# ...

# %%
df.filter((pl.col('sub_type') == 0) & (pl.col('equipment_type') == '[creature]'))
# Out:
# shape: (130, 30)
# ┌───────────┬───────────┬──────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ id        ┆ name      ┆ name2    ┆ json      ┆ … ┆ armor_typ ┆ display_e ┆ display_r ┆ display_u │
# │ ---       ┆ ---       ┆ ---      ┆ ---       ┆   ┆ e         ┆ quipment_ ┆ arity     ┆ sable_job │
# │ i64       ┆ str       ┆ str      ┆ str       ┆   ┆ ---       ┆ type      ┆ ---       ┆ ---       │
# │           ┆           ┆          ┆           ┆   ┆ str       ┆ ---       ┆ str       ┆ str       │
# │           ┆           ┆          ┆           ┆   ┆           ┆ str       ┆           ┆           │
# ╞═══════════╪═══════════╪══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 63000     ┆ 佛拉斯    ┆ Faras    ┆ {"[name]" ┆ … ┆           ┆ 宠物      ┆ 高级      ┆ 全部职业  │
# │           ┆           ┆          ┆ : ["佛拉  ┆   ┆           ┆           ┆           ┆           │
# ...

# %%
df.select('usable_job', 'display_usable_job')
# Out:
# shape: (63_788, 2)
# ┌─────────────────────────────────┬────────────────────┐
# │ usable_job                      ┆ display_usable_job │
# │ ---                             ┆ ---                │
# │ list[str]                       ┆ str                │
# ╞═════════════════════════════════╪════════════════════╡
# │ ["[all]"]                       ┆ 全部职业           │
# │ ["[all]"]                       ┆ 全部职业           │
# │ ["[all]"]                       ┆ 全部职业           │
# │ ["[all]"]                       ┆ 全部职业           │
# │ ["[all]"]                       ┆ 全部职业           │
# │ …                               ┆ …                  │
# │ ["[swordman]", "[demonic sword… ┆ 鬼剑士,黑暗武士    │
# │ ["[all]"]                       ┆ 全部职业           │
# │ ["[all]"]                       ┆ 全部职业           │
# │ ["[all]"]                       ┆ 全部职业           │
# │ ["[all]"]                       ┆ 全部职业           │
# └─────────────────────────────────┴────────────────────┘

# %%
df.filter(pl.col('equipment_type') == '[ring]')
# Out:
# shape: (1_884, 30)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ id        ┆ name      ┆ name2     ┆ json      ┆ … ┆ armor_typ ┆ display_e ┆ display_r ┆ display_ │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ e         ┆ quipment_ ┆ arity     ┆ usable_j │
# │ i64       ┆ str       ┆ str       ┆ str       ┆   ┆ ---       ┆ type      ┆ ---       ┆ ob       │
# │           ┆           ┆           ┆           ┆   ┆ str       ┆ ---       ┆ str       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆ str       ┆           ┆ str      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 24012     ┆ (旧) 褪色 ┆ Fade      ┆ {"[name]" ┆ … ┆           ┆ 戒指      ┆ 普通      ┆ 全部职业 │
# │           ┆ 的青铜戒  ┆ Bronze    ┆ : ["(旧)  ┆   ┆           ┆           ┆           ┆          │
# ...
